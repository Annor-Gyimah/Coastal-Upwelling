# %% [markdown]
# ## 📦 Data Access and Preparation
#
# This study uses freely available **reanalysis and satellite products** covering the period **2010–2017**.
# All raw datasets are publicly accessible through open repositories or data APIs.
#
# | Dataset | Provider | Variables Used | Temporal Res. | Spatial Res. | Access |
# |----------|-----------|----------------|----------------|----------------|---------|
# | ERA5 Reanalysis | European Centre for Medium-Range Weather Forecasts (ECMWF) via Copernicus CDS | 10 m wind components (u10, v10) | Monthly / 6-hourly | 0.25° × 0.25° | https://cds.climate.copernicus.eu |
# | CMEMS GLORYS12V1 | Copernicus Marine Environment Monitoring Service | Sea-surface height (adt), ocean currents (uo, vo), salinity (sos) | Monthly | 0.083° | https://marine.copernicus.eu |
# | MUR SST v4.1 | NASA Jet Propulsion Laboratory (JPL) | Sea-surface temperature (sst) | Daily | 0.01° | https://podaac.jpl.nasa.gov/dataset/MUR-JPL-L4-GLOB-v4.1 |
# | SMAP SSS L3 | NASA JPL PO.DAAC | Sea-surface salinity (sss) | 8-day | 0.25° | https://podaac.jpl.nasa.gov/dataset/SMAP_JPL_L3_SSS_CAP_8DAY-R4 |
#
#
# Each dataset is cited in the manuscript and must be acknowledged according to the provider’s data-use policy.
